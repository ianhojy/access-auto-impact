# %%
import pandas as pd
from scipy import stats
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %%
filename = 'responses.xlsx'
num_pre_cols = 4
num_post_cols = 3

min_val = 1
max_val = 6

question_categories = {
    'Skills': 7,
    'Self-Perception': 6,
    'Curiosity & Aspirations': 6
}

# %%
df = pd.read_excel(filename)
df = df.iloc[:, num_pre_cols: -num_post_cols]
num_cols = len(df.columns)

# %%
num_cols_even = num_cols % 2 == 0
assert num_cols_even

num_pre_post_qns = int(num_cols/2)
print(f'There are {num_pre_post_qns} pre-post questions')

assert sum(question_categories.values()) == num_pre_post_qns
# Out:
# There are 19 pre-post questions

# %%
unique_vals = set(df.stack().unique())
assert unique_vals == set(range(min_val, max_val+1))

# %%
def get_confidence_of_difference(array1, array2):
    _, p_value = stats.ttest_ind(array1, array2)
    return round(100 * (1 - p_value), 1)

# %%
def make_square_dataframe(df, num_qns=1):
    
    new_index = list(range(1, num_qns*6+1))
    new_columns = list(range(1, num_qns*6+1))

 
    missing_rows = [r for r in new_index if r not in df.index]
    missing_columns = [c for c in new_columns if c not in df.columns]
    
    for row in missing_rows:
        df.loc[row] = 0
    
    for col in missing_columns:
        df[col] = 0
    
    df = df.sort_index(axis=0)
    df = df.sort_index(axis=1)
    
    return df

# %%
def get_breakdown(res, num_qns=1):

    improve = 0
    decline = 0
    same_low = 0
    same_high = 0
    total = 0
    
    max_val = num_qns * 6

    for row in range(1, max_val + 1, 1):
        for col in range(1, max_val + 1, 1):
            val = res.loc[row, col]
            if col > row:
                improve += val
            elif col < row:
                decline += val
            elif col == row:
                if col <= max_val / 2:
                    same_low += val
                else:
                    same_high += val                
            else:
                raise Exception('False Logic')

            total += val
            
    return {
        'improve': improve, 
        'decline': decline, 
        'same_low': same_low, 
        'same_high': same_high, 
        'total': total
    }

# %%
results = dict()

bef_index = 0

for cat, num_qns in question_categories.items():
    
    inner_results = list()
    
    for _ in range(num_qns):
        
        inner_dict = dict()
        
        aft_index = bef_index + 1
        
        bef_qn = df.columns[bef_index]
        aft_qn = df.columns[aft_index]
        
        inner_dict['before_qn'] = bef_qn
        inner_dict['after_qn'] = aft_qn
        
        
        temp = df.iloc[:, [bef_index, aft_index]]
        temp.rename(columns={
            bef_qn: 'before',
            aft_qn: 'after'
        }, inplace=True)
        
        before_mean = round(temp['before'].mean(), 2)
        after_mean = round(temp['after'].mean(), 2)
        abs_change = round(after_mean - before_mean, 2)
        pct_change = round((abs_change / before_mean) * 100, 1)
        confidence_diff = get_confidence_of_difference(temp['before'], temp['after'])
        
        inner_dict.update({
            'before_mean': before_mean,
            'after_mean': after_mean,
            'abs_change': abs_change,
            'pct_change': pct_change,
            'confidence_diff': confidence_diff
        })
        
        
        groupby_temp = make_square_dataframe(
            temp.groupby(['before', 'after'])
                .size()
                .unstack()
                .fillna(0)
                .astype(int)
        )
        
        inner_dict.update(get_breakdown(groupby_temp))
        
        inner_results.append(inner_dict)
        
        bef_index += 2
        
    cat_start_index = aft_index - 2 * num_qns + 1
    
    cat_before = df.iloc[:, np.arange(
        cat_start_index, 
        cat_start_index + num_qns * 2, 2)].sum(axis=1)
    
    cat_after = df.iloc[:, np.arange(
        cat_start_index + 1, 
        cat_start_index + num_qns * 2 + 1, 2)].sum(axis=1)

    cat_combined = pd.concat([cat_before, cat_after], axis=1).rename(
        columns={0: 'cat_before', 1: 'cat_after'})
    
    cat_groupby_temp = make_square_dataframe(
        cat_combined.groupby(['cat_before', 'cat_after'])
            .size()
            .unstack()
            .fillna(0)
            .astype(int),
    num_qns=num_qns)
        
    cat_before_mean = round(cat_combined['cat_before'].mean(), 2)
    cat_after_mean = round(cat_combined['cat_after'].mean(), 2)
    cat_abs_change = round(cat_after_mean - cat_before_mean, 2)
    cat_pct_change = round((cat_abs_change / cat_before_mean) * 100, 1)
    cat_confidence_diff = get_confidence_of_difference(
        cat_combined['cat_before'], cat_combined['cat_after'])
        
    cat_results = dict()
    
    cat_results['cat_num_qns'] = num_qns
    cat_results.update({
        'cat_before_mean': cat_before_mean,
        'cat_after_mean': cat_after_mean,
        'cat_abs_change': cat_abs_change,
        'cat_pct_change': cat_pct_change,
        'cat_confidence_diff': cat_confidence_diff
    })
    
    cat_results.update(get_breakdown(cat_groupby_temp, num_qns=num_qns))
    cat_results['question_results'] = inner_results
    
    results[cat] = cat_results

# %%
results
# Out:
# {'Skills': {'cat_num_qns': 7,
#   'cat_before_mean': 26.32,
#   'cat_after_mean': 33.44,
#   'cat_abs_change': 7.12,
#   'cat_pct_change': 27.1,
#   'cat_confidence_diff': 99.8,
#   'improve': 17,
#   'decline': 3,
#   'same_low': 0,
#   'same_high': 5,
#   'total': 25,
#   'question_results': [{'before_qn': 'Before this programme, I was confident to give a presentation and speak publicly.',
#     'after_qn': 'After this programme, I am confident to give a presentation and speak publicly.',
#     'before_mean': 3.52,
#     'after_mean': 4.44,
#     'abs_change': 0.92,
#     'pct_change': 26.1,
#     'confidence_diff': 96.8,
#     'improve': 13,
#     'decline': 2,
#     'same_low': 3,
#     'same_high': 7,
#     'total': 25},
#    {'before_qn': 'Before this programme, I knew how to create and deliver an impactful presentation.',
#     'after_qn': 'After this programme, I know how to create and deliver an impactful presentation.',
#     'before_mean': 3.44,
#     'after_mean': 4.56,
#     'abs_change': 1.12,
#     'pct_change': 32.6,
#     'confidence_diff': 99.5,
#     'improve': 14,
#     'decline': 2,
#     'same_low': 2,
#     'same_high': 7,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was familiar with the steps and frameworks that could be used to analyse a problem statement.',
#     'after_qn': 'After this programme, I am familiar with the steps and frameworks that could be used to analyse a problem statement.',
#     'before_mean': 3.52,
#     'after_mean': 4.68,
#     'abs_change': 1.16,
#     'pct_change': 33.0,
#     'confidence_diff': 99.8,
#     'improve': 16,
#     'decline': 1,
#     'same_low': 1,
#     'same_high': 7,
#     'total': 25},
#    {'before_qn': 'Before this programme, I knew how to apply critical thinking when analysing a problem.',
#     'after_qn': 'After this programme, I know how to apply critical thinking when analysing a problem.',
#     'before_mean': 3.72,
#     'after_mean': 4.72,
#     'abs_change': 1.0,
#     'pct_change': 26.9,
#     'confidence_diff': 99.5,
#     'improve': 14,
#     'decline': 2,
#     'same_low': 3,
#     'same_high': 6,
#     'total': 25},
#    {'before_qn': 'Before this programme, I knew how to apply creative thinking when solving a problem.',
#     'after_qn': 'After this programme, I know how to apply creative thinking when solving a problem.',
#     'before_mean': 3.8,
#     'after_mean': 4.72,
#     'abs_change': 0.92,
#     'pct_change': 24.2,
#     'confidence_diff': 98.9,
#     'improve': 14,
#     'decline': 3,
#     'same_low': 1,
#     'same_high': 7,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was comfortable with brainstorming and crafting solutions to a problem statement.',
#     'after_qn': 'After this programme, I am comfortable with brainstorming and crafting solutions to a problem statement.',
#     'before_mean': 4.24,
#     'after_mean': 5.12,
#     'abs_change': 0.88,
#     'pct_change': 20.8,
#     'confidence_diff': 99.0,
#     'improve': 13,
#     'decline': 1,
#     'same_low': 1,
#     'same_high': 10,
#     'total': 25},
#    {'before_qn': 'Before this programme, I knew how teams can learn to work, collaborate and communicate effectively.',
#     'after_qn': 'After this programme, I know how teams can learn to work, collaborate and communicate effectively.',
#     'before_mean': 4.08,
#     'after_mean': 5.2,
#     'abs_change': 1.12,
#     'pct_change': 27.5,
#     'confidence_diff': 99.7,
#     'improve': 15,
#     'decline': 2,
#     'same_low': 1,
#     'same_high': 7,
#     'total': 25}]},
#  'Self-Perception': {'cat_num_qns': 6,
#   'cat_before_mean': 23.04,
#   'cat_after_mean': 28.6,
#   'cat_abs_change': 5.56,
#   'cat_pct_change': 24.1,
#   'cat_confidence_diff': 99.6,
#   'improve': 16,
#   'decline': 4,
#   'same_low': 1,
#   'same_high': 4,
#   'total': 25,
#   'question_results': [{'before_qn': 'Before this programme, I was aware of my personality (strengths and weaknesses) when working in a team.',
#     'after_qn': 'After this programme, I am aware of my personality (strengths and weaknesses) when working in a team.',
#     'before_mean': 3.76,
#     'after_mean': 4.64,
#     'abs_change': 0.88,
#     'pct_change': 23.4,
#     'confidence_diff': 97.2,
#     'improve': 11,
#     'decline': 2,
#     'same_low': 1,
#     'same_high': 11,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was confident to contribute and communicate my ideas in a team.',
#     'after_qn': 'After this programme, I am confident to contribute and communicate my ideas in a team.',
#     'before_mean': 4.08,
#     'after_mean': 5.08,
#     'abs_change': 1.0,
#     'pct_change': 24.5,
#     'confidence_diff': 99.1,
#     'improve': 12,
#     'decline': 1,
#     'same_low': 1,
#     'same_high': 11,
#     'total': 25},
#    {'before_qn': 'Before this programme, I felt that I had useful skills and ideas.',
#     'after_qn': 'After this programme, I feel that I have useful skills and ideas.',
#     'before_mean': 3.96,
#     'after_mean': 4.92,
#     'abs_change': 0.96,
#     'pct_change': 24.2,
#     'confidence_diff': 98.9,
#     'improve': 12,
#     'decline': 3,
#     'same_low': 1,
#     'same_high': 9,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was confident to take on leadership responsibilities in a team.',
#     'after_qn': 'After this programme, I am confident to take on leadership responsibilities in a team.',
#     'before_mean': 3.4,
#     'after_mean': 4.36,
#     'abs_change': 0.96,
#     'pct_change': 28.2,
#     'confidence_diff': 98.3,
#     'improve': 14,
#     'decline': 2,
#     'same_low': 2,
#     'same_high': 7,
#     'total': 25},
#    {'before_qn': 'Before this programme, I felt that I was an independent and effective team member.',
#     'after_qn': 'After this programme, I feel that I am an independent and effective team member.',
#     'before_mean': 3.76,
#     'after_mean': 4.72,
#     'abs_change': 0.96,
#     'pct_change': 25.5,
#     'confidence_diff': 99.3,
#     'improve': 12,
#     'decline': 1,
#     'same_low': 2,
#     'same_high': 10,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was aware of the kinds of project tasks that I like and/or dislike.',
#     'after_qn': 'After this programme, I am aware of the kinds of project tasks that I like and/or dislike.',
#     'before_mean': 4.08,
#     'after_mean': 4.88,
#     'abs_change': 0.8,
#     'pct_change': 19.6,
#     'confidence_diff': 98.0,
#     'improve': 12,
#     'decline': 1,
#     'same_low': 1,
#     'same_high': 11,
#     'total': 25}]},
#  'Curiosity & Aspirations': {'cat_num_qns': 6,
#   'cat_before_mean': 23.28,
#   'cat_after_mean': 27.24,
#   'cat_abs_change': 3.96,
#   'cat_pct_change': 17.0,
#   'cat_confidence_diff': 95.3,
#   'improve': 16,
#   'decline': 1,
#   'same_low': 2,
#   'same_high': 6,
#   'total': 25,
#   'question_results': [{'before_qn': 'Before this programme, I was familiar with the type of work done by companies in the banking and/or legal sectors.',
#     'after_qn': 'After this programme, I am familiar with the type of work done by companies in the banking and/or legal sectors.',
#     'before_mean': 3.4,
#     'after_mean': 4.6,
#     'abs_change': 1.2,
#     'pct_change': 35.3,
#     'confidence_diff': 99.5,
#     'improve': 14,
#     'decline': 0,
#     'same_low': 3,
#     'same_high': 8,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was familiar with the kinds of jobs in the banking and/or legal sectors.',
#     'after_qn': 'After this programme, I am familiar with the kinds of jobs in the banking and/or legal sectors.',
#     'before_mean': 3.76,
#     'after_mean': 4.72,
#     'abs_change': 0.96,
#     'pct_change': 25.5,
#     'confidence_diff': 98.2,
#     'improve': 14,
#     'decline': 1,
#     'same_low': 2,
#     'same_high': 8,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was familiar with the skills required to work in the banking and/or legal sectors.',
#     'after_qn': 'After this programme, I am familiar with the skills required to work in the banking and/or legal sectors.',
#     'before_mean': 3.48,
#     'after_mean': 4.52,
#     'abs_change': 1.04,
#     'pct_change': 29.9,
#     'confidence_diff': 98.5,
#     'improve': 14,
#     'decline': 0,
#     'same_low': 3,
#     'same_high': 8,
#     'total': 25},
#    {'before_qn': 'Before this programme, I was motivated to pursue my ideal career and job.',
#     'after_qn': 'After this programme, I am motivated to pursue my ideal career and job.',
#     'before_mean': 4.44,
#     'after_mean': 4.48,
#     'abs_change': 0.04,
#     'pct_change': 0.9,
#     'confidence_diff': 8.6,
#     'improve': 7,
#     'decline': 4,
#     'same_low': 4,
#     'same_high': 10,
#     'total': 25},
#    {'before_qn': 'Before this programme, I knew what I had to do (skills, experiences) to pursue my ideal career and job.',
#     'after_qn': 'After this programme, I know what I have to do (skills, experiences) to pursue my ideal career and job.',
#     'before_mean': 4.24,
#     'after_mean': 4.44,
#     'abs_change': 0.2,
#     'pct_change': 4.7,
#     'confidence_diff': 41.7,
#     'improve': 7,
#     'decline': 4,
#     'same_low': 3,
#     'same_high': 11,
#     'total': 25},
#    {'before_qn': 'Before this programme, I am motivated to think about my goals (professional / personal) in life.',
#     'after_qn': 'After this programme, I am motivated to think about my goals (professional / personal) in life.',
#     'before_mean': 3.96,
#     'after_mean': 4.48,
#     'abs_change': 0.52,
#     'pct_change': 13.1,
#     'confidence_diff': 80.2,
#     'improve': 8,
#     'decline': 2,
#     'same_low': 3,
#     'same_high': 12,
#     'total': 25}]}}
